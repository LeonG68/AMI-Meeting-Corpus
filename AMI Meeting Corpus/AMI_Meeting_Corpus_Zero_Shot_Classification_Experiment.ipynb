# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.2 MB 4.2 MB/s
#      |████████████████████████████████| 6.6 MB 45.0 MB/s
#      |████████████████████████████████| 596 kB 51.8 MB/s
#      |████████████████████████████████| 86 kB 5.3 MB/s

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
sentences = [   
    'We need to solve the satellite issue for our droplet generator',
    'John is running late',
    'How is everyone feeling today',
    'We have detected a leak on MH-643',
    'The humidity level is an indication of a continous water leak, not outgassing',
    'We have to swap the DGLM on MH-643',
    'Try cannabalizing the board from MH-643'
]

for x in sentences:
  res = classifier(
      x,
      candidate_labels = ['problem statement', 'answer', 'question']
  )

  print(res)
# Out:
# {'sequence': 'We need to solve the satellite issue for our droplet generator', 'labels': ['problem statement', 'question', 'answer'], 'scores': [0.7034192085266113, 0.28153109550476074, 0.015049664303660393]}
# {'sequence': 'John is running late', 'labels': ['problem statement', 'answer', 'question'], 'scores': [0.5256679058074951, 0.26681676506996155, 0.20751535892486572]}
# {'sequence': 'How is everyone feeling today', 'labels': ['question', 'problem statement', 'answer'], 'scores': [0.913922131061554, 0.05090605095028877, 0.03517182543873787]}
# {'sequence': 'We have detected a leak on MH-643', 'labels': ['problem statement', 'question', 'answer'], 'scores': [0.7795217037200928, 0.12338682264089584, 0.09709151089191437]}
# {'sequence': 'The humidity level is an indication of a continous water leak, not outgassing', 'labels': ['problem statement', 'answer', 'question'], 'scores': [0.5204609036445618, 0.24202033877372742, 0.2375188022851944]}
# {'sequence': 'We have to swap the DGLM on MH-643', 'labels': ['problem statement', 'question', 'answer'], 'scores': [0.3759421706199646, 0.34974873065948486, 0.27430906891822815]}
# {'sequence': 'Try cannabalizing the board from MH-643', 'labels': ['problem statement', 'question', 'answer'], 'scores': [0.4298824667930603, 0.3902381360530853, 0.17987941205501556]}
